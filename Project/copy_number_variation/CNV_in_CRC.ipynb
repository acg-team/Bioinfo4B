# %% [markdown]
# ## Pattern of Copy Number Variation in Colorectal Cancer
#
# The goal of the project is to perform somatic copy number variation analysis in colorectal cancer using copy number segment file from SNP array data.

# %% [markdown]
# First at all, let's import the packages needed for the project.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.1 Introduction
# Copy Number Variations (CNV) refers to the duplication or deletion of DNA segments larger than 1 kb. They are widespread among humans - on an average 12 CNVs exist per individual in comparison to the reference genome. In colorectal cancer(CRC), there are three major molecular pathways, including the chromosomal instability (found in 85% cases), microsatellite instability and CpG island methylator phenotype pathways. Somatic copy number variations are somatic changes that cause the gain or loss of DNA sections (>1 kb) in a tumor genome. \
# Today, we are going to look at copy number segment file of colorectal cancer downloaded from TCGA.

# %%
cna_data = pd.read_csv("../data/COADREAD_cnv_hg19.seg.txt",sep="\t")
cna_data.head()
# Out:
#                          Sample  Chromosome      Start        End  Num_Probes  \
# 0  TCGA-3L-AA1B-10A-01D-A36Z-01           1    3218610  247813706      129103
# 1  TCGA-3L-AA1B-10A-01D-A36Z-01           2     484222  218257449      116712
# 2  TCGA-3L-AA1B-10A-01D-A36Z-01           2  218257643  218258530           2
# 3  TCGA-3L-AA1B-10A-01D-A36Z-01           2  218259653  242476062       14563
# 4  TCGA-3L-AA1B-10A-01D-A36Z-01           3    2212571   27474740       14707
#
#    Segment_Mean
# 0        0.0023
# 1        0.0074
# 2       -1.9301
# 3        0.0116
# 4        0.0071

# %% [markdown]
# This files are segmented into genomic regions with the estimated copy number for each region. The GDC further transforms these copy number values into **segment mean** values, which are equal to log2(copy-number/ 2). Diploid regions will have a segment mean of zero, amplified regions will have positive values, and deletions will have negative values.
#
# To help you understand the dataset, you are recommended to read the copy number variation pipelines that TCGA has used for CNV detection: https://docs.gdc.cancer.gov/Data/Bioinformatics_Pipelines/CNV_Pipeline/

# %% [markdown]
# ### 1.2 Data Processing

# %% [markdown]
# Number of unique samples in this dataset

# %%
## your code

# %% [markdown]
# Number of calls for each sample

# %%
## your code

# %% [markdown]
# Read the definition of TCGA barcode https://docs.gdc.cancer.gov/Encyclopedia/pages/TCGA_Barcode/ <br>
# how would you filter out the copy number segs from normal samples and keep only those from tumor samples? <br>
# (hint: split the barcode for each sample)

# %%
## your code

# %% [markdown]
# how many unique tumor samples are left?

# %%
## your code

# %% [markdown]
# According to https://docs.gdc.cancer.gov/Data/Bioinformatics_Pipelines/CNV_Pipeline/ <br>
# What kind of copy number alternations are considered copy number losses? And what are considered copy number gains?
# Keep only copy number gains and copy number losses

# %%
## your code

# %% [markdown]
# ### 1.3 Data exploration

# %% [markdown]
# Number of copy number gain and loss in each chromosome (hints: barplot)

# %%
## your code
# Out:
# Text(0, 0.5, 'Count of Copy Number Gain/Loss')

# %% [markdown]
# Length distribution of copy number gain and loss (hints: boxplot)

# %%
## your code

# %% [markdown]
# ### 1.4 Pattern of CNV between MSS/MSI in CRC
#
# Microsatellite instability and chromosomal instability are two major molecular characteristics in colorectal cancer. With MSI status provided for each samples, could you try to find out the distinct features of copy number alternations in MSI-H and MSS/MSI-L group?
#
# You might get some inspirations from this paper: <br>
# Trautmann, Karolin, et al. "Chromosomal instability in microsatellite-unstable and stable colon cancer." Clinical Cancer Research 12.21 (2006): 6379-6385.
#
#
# hint: try to get copy number frequency plot for each group with CNVkit package. Or if you want, you also can try some R packages, like "copynumber" and "GenVisR".

# %%
### your code
